# %% [markdown]
# # Regresión lineal

# %% [markdown]
# ## CO Monóxido de Carbono

# %%
# Paquetes necesarios
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../datos/promedios_mensuales/CO_mensual.csv')
df.head()
# Out:
#         fecha  noreste_monoxido_de_carbono  suroeste_monoxido_de_carbono  \
# 0  2005-01-31                    17.379032                     17.501344
# 1  2005-02-28                    16.300595                     14.505952
# 2  2005-03-31                    15.766129                     13.456989
# 3  2005-04-30                    14.031944                     14.483333
# 4  2005-05-31                    16.165323                     14.461022
#
#    noroeste_monoxido_de_carbono  sureste_monoxido_de_carbono  \
# 0                     18.849462                    22.038978
# 1                     16.983631                    19.949405
# 2                     17.076613                    17.314516
# 3                     18.434722                    18.925000
# 4                     16.596774                    20.306452
#
#    centro_monoxido_de_carbono
# 0                   22.013441
# 1                   19.897321
# 2                   20.239247
# 3                   21.051389
# 4                   19.369624

# %%
# Convirtiendo la fecha
import datetime as dt
df['fecha'] = pd.to_datetime(df['fecha'])
df['fecha'] = df['fecha'].map(dt.datetime.toordinal)

# %%
def obtener_regresion(X, y, zona):
    print(f"\nRegresión Lineal para Monóxido de Carbono (CO) en {zona}")
    # Dividiendo conjunto de entrenamiento y prueba
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)
    
    # Entrenando al modelo
    from sklearn.linear_model import LinearRegression
    lr = LinearRegression()
    lr.fit(X_train, y_train)
    print(f"Score del Modelo: {lr.score(X_train, y_train)}")
    
    # Evaluando modelo de regresión lineal
    y_pred = lr.predict(X_test)
    
    print(" ### Resultados ###")
    print("Conjunto de prueba (test)")
    print(y_test)
    print("Predicción")
    print(y_pred)
    
    # Visualizar los resultados de entrenamiento
    plt.scatter(X_train, y_train, color = "red")
    plt.plot(X_train, lr.predict(X_train), color = "blue")
    plt.title("Contaminación de Monóxido de Carbono (CO) en " + zona + " (Entrenamiento)")
    plt.xlabel("Fecha")
    plt.ylabel("Nivel de Contaminación")
    plt.show()

# %%
X = df.iloc[:,0].values
X = X.reshape(-1,1)
zonas = ["Noreste", "Suroeste", "Noroeste", "Sureste", "Centro"]
for i in range(1,6):
    obtener_regresion(X, df.iloc[:,i].values, zonas[i-1])
# Out:
# Regresión Lineal para Monóxido de Carbono (CO) en Noreste
# Score del Modelo: 0.5178267016091009
#  ### Resultados ###
# Conjunto de prueba (test)
# [ 8.29166667 11.98521505  6.49962742 11.09077381  9.52218495 14.83467742
#  12.70295699  7.48507441  9.03238691 13.4233871  12.35972222  9.03092903
#   7.25875914  6.50102688  6.35010161  9.82193118 12.09913793  9.29166667
#   8.49027419  9.6438172   8.88194444  4.51581183  8.78597312  4.87199463
#   7.24150753  6.929125    9.76388889 12.31586022  6.43821778 10.16846882
